# %% [markdown]
# # Supplementary Notebook 1: AQI Breakpoints Transformation

# %%
import pandas as pd
import requests
from io import StringIO
import hashlib
from pathlib import Path
import os

# %%
# OPENAQ_DIR = Path(os.getenv('OPENAQ_DIR'))
DATASET_DIR = Path("datasets/")
CACHE_DIR = Path("cache/")
WEIGHTS_DIR = Path("weights/")
OUTPUT_DIR = Path("output/")

# print(OPENAQ_HASH)


os.makedirs(DATASET_DIR, exist_ok=True)
os.makedirs(CACHE_DIR, exist_ok=True)
os.makedirs(WEIGHTS_DIR, exist_ok=True)
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
MOLAR_MASSES = {
    "NO2": 46.0055,
    "O3": 48.00,
    "CO": 28.01,
    "SO2": 64.066,
}

GAS_MAPPINGS = {
    "Carbon monoxide": "CO",
    "Nitrogen dioxide (NO2)": "NO2",
    "Ozone" : "O3",
    "PM2.5 - Local Conditions": "PM25",
    "PM10 Total 0-10um STP": "PM10",
    "Sulfur dioxide": "SO2",
}

# %%
df = pd.read_csv("https://aqs.epa.gov/aqsweb/documents/codetables/aqi_breakpoints.csv")
df = df.drop(['Parameter Code','Low AQI','High AQI'], axis=1)
df = df[df['Parameter'].isin(GAS_MAPPINGS.keys())]
df['Parameter'] = df['Parameter'].map(GAS_MAPPINGS)

# Filter out
df = df[~(
    ((df['Parameter'] == 'O3') & (df['Duration Description'] == '8-HR RUN AVG BEGIN HOUR')) |
    ((df['Parameter'] == 'PM10') & (df['Duration Description'] == '24-HR BLK AVG')) |
    ((df['Parameter'] == 'PM25') & (df['Duration Description'] == '24-HR BLK AVG')) |
    ((df['Parameter'] == 'SO2') & (df['Duration Description'] == '24-HR BLK AVG'))
)]

# %%
def to_ugm3(row, col):
    gas = row['Parameter']
    val = row[col]
    if gas in ["PM25", "PM10"] or pd.isna(val):
        return val
    unit = "ppb" if gas in ["NO2", "SO2"] else "ppm"
    molar_mass = MOLAR_MASSES[gas]
    if unit == "ppm":
        return val * 1000 * molar_mass / 24.45
    else:
        return val * molar_mass / 24.45

# Apply conversion
df["Low Breakpoint (ug/m3)"] = df.apply(lambda row: to_ugm3(row, "Low Breakpoint"), axis=1)
df["High Breakpoint (ug/m3)"] = df.apply(lambda row: to_ugm3(row, "High Breakpoint"), axis=1)

# %%
df
# Out:
#    Parameter Duration Code   Duration Description             AQI Category  \
# 14        CO             Z  8-HR RUN AVG END HOUR                     GOOD
# 15        CO             Z  8-HR RUN AVG END HOUR                 MODERATE
# 16        CO             Z  8-HR RUN AVG END HOUR  UNHEALTHY FOR SENSITIVE
# 17        CO             Z  8-HR RUN AVG END HOUR                UNHEALTHY
# 18        CO             Z  8-HR RUN AVG END HOUR           VERY UNHEALTHY
# 19        CO             Z  8-HR RUN AVG END HOUR                HAZARDOUS
# 20        CO             Z  8-HR RUN AVG END HOUR                HAZARDOUS
# 21       NO2             1                 1 HOUR                     GOOD
# 22       NO2             1                 1 HOUR                 MODERATE
# 23       NO2             1                 1 HOUR  UNHEALTHY FOR SENSITIVE
# 24       NO2             1                 1 HOUR                UNHEALTHY
# 25       NO2             1                 1 HOUR           VERY UNHEALTHY
# 26       NO2             1                 1 HOUR                HAZARDOUS
# 27       NO2             1                 1 HOUR                HAZARDOUS
# 28        O3             1                 1 HOUR                     NONE
# 29        O3             1                 1 HOUR  UNHEALTHY FOR SENSITIVE
# 30        O3             1                 1 HOUR                UNHEALTHY
# 31        O3             1                 1 HOUR           VERY UNHEALTHY
# 32        O3             1                 1 HOUR                HAZARDOUS
# 33        O3             1                 1 HOUR                HAZARDOUS
# 40      PM10             7                24 HOUR                     GOOD
# 41      PM10             7                24 HOUR                 MODERATE
# 42      PM10             7                24 HOUR  UNHEALTHY FOR SENSITIVE
# 43      PM10             7                24 HOUR                UNHEALTHY
# 44      PM10             7                24 HOUR           VERY UNHEALTHY
# 45      PM10             7                24 HOUR                HAZARDOUS
# 46      PM10             7                24 HOUR                HAZARDOUS
# 54      PM25             7                24 HOUR                     GOOD
# 55      PM25             7                24 HOUR                 MODERATE
# 56      PM25             7                24 HOUR  UNHEALTHY FOR SENSITIVE
# 57      PM25             7                24 HOUR                UNHEALTHY
# 58      PM25             7                24 HOUR           VERY UNHEALTHY
# 59      PM25             7                24 HOUR                HAZARDOUS
# 60      PM25             7                24 HOUR                HAZARDOUS
# 68       SO2             1                 1 HOUR                     GOOD
# 69       SO2             1                 1 HOUR                 MODERATE
# 70       SO2             1                 1 HOUR  UNHEALTHY FOR SENSITIVE
# 71       SO2             1                 1 HOUR                UNHEALTHY
# 72       SO2             1                 1 HOUR                UNHEALTHY
#
#     Low Breakpoint  High Breakpoint  Low Breakpoint (ug/m3)  \
# 14           0.000            4.400                0.000000
# 15           4.500            9.400             5155.214724
# 16           9.500           12.400            10883.231084
# 17          12.500           15.400            14320.040900
# 18          15.500           30.400            17756.850716
# 19          30.500           50.400            34940.899796
# 20          50.400        99999.900            57738.404908
# 21           0.000           53.000                0.000000
# 22          54.000          100.000              101.607239
# 23         101.000          360.000              190.043170
# 24         361.000          649.000              679.263211
# 25         650.000         1249.000             1223.050102
# 26        1250.000         2049.000             2352.019427
# 27        2050.000        99999.000             3857.311861
# 28           0.000            0.124                0.000000
# 29           0.125            0.164              245.398773
# 30           0.165            0.204              323.926380
# 31           0.205            0.404              402.453988
# 32           0.405            0.604              795.092025
# 33           0.605        99999.900             1187.730061
# 40           0.000           54.000                0.000000
# 41          55.000          154.000               55.000000
# 42         155.000          254.000              155.000000
# 43         255.000          354.000              255.000000
# 44         355.000          424.000              355.000000
# 45         425.000          604.000              425.000000
# 46         605.000        99999.900              605.000000
# 54           0.000            9.000                0.000000
# 55           9.100           35.400                9.100000
# 56          35.500           55.400               35.500000
# 57          55.500          125.400               55.500000
# 58         125.500          225.400              125.500000
# 59         225.500          325.400              225.500000
# 60         325.500        99999.900              325.500000
# 68           0.000           35.000                0.000000
# 69          36.000           75.000               94.330307
# 70          76.000          185.000              199.141759
# 71         186.000          304.000              487.373252
# 72         305.000        99999.000              799.187321
#
#     High Breakpoint (ug/m3)
# 14             5.040654e+03
# 15             1.076867e+04
# 16             1.420548e+04
# 17             1.764229e+04
# 18             3.482634e+04
# 19             5.773840e+04
# 20             1.145602e+08
# 21             9.972562e+01
# 22             1.881616e+02
# 23             6.773816e+02
# 24             1.221168e+03
# 25             2.350138e+03
# 26             3.855430e+03
# 27             1.881597e+05
# 28             2.434356e+02
# 29             3.219632e+02
# 30             4.004908e+02
# 31             7.931288e+02
# 32             1.185767e+03
# 33             1.963188e+08
# 40             5.400000e+01
# 41             1.540000e+02
# 42             2.540000e+02
# 43             3.540000e+02
# 44             4.240000e+02
# 45             6.040000e+02
# 46             9.999990e+04
# 54             9.000000e+00
# 55             3.540000e+01
# 56             5.540000e+01
# 57             1.254000e+02
# 58             2.254000e+02
# 59             3.254000e+02
# 60             9.999990e+04
# 68             9.171002e+01
# 69             1.965215e+02
# 70             4.847530e+02
# 71             7.965670e+02
# 72             2.620260e+05

# %%
df.to_csv(DATASET_DIR / "aqi_breakpoints.csv", index=False)
